# %% [markdown]
# <a href="https://colab.research.google.com/github/madhubantideb/learning_new/blob/main/ISM_663_Day0_Mady.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ISM663
# - Google Colab Tutorial

# %%
print("Hello All!\n")
print("Mady Here .. Nice to meet you")
# Out:
# Hello All!
#
# Mady Here .. Nice to meet you
